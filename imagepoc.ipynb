# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image  # PIL python imaging  library

# %%
myimg = Image.open(r"C:\Users\User\Downloads\elephant.jpeg")

# %%
myimg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=211x148>

# %%
myimg = Image.open(r"C:\Users\User\Downloads\baby.jpeg")

# %%
myimg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x148>

# %%
type(myimg)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
myimg.show()

# %%
img_arr  = np.asarray(myimg)
img_arr
# Out:
# array([[[ 88,  14,   3],
#         [ 87,  13,   0],
#         [ 85,  11,   0],
#         ...,
#         [251, 255, 243],
#         [251, 255, 243],
#         [250, 255, 242]],
#
#        [[ 89,  15,   2],
#         [ 87,  13,   0],
#         [ 85,  11,   0],
#         ...,
#         [251, 255, 245],
#         [251, 255, 245],
#         [250, 255, 244]],
#
#        [[ 89,  15,   2],
#         [ 88,  14,   1],
#         [ 86,  12,   0],
#         ...,
#         [251, 255, 249],
#         [251, 255, 249],
#         [250, 255, 248]],
#
#        ...,
#
#        [[226, 226, 238],
#         [219, 219, 231],
#         [215, 215, 225],
#         ...,
#         [ 96,  41,   2],
#         [ 92,  40,   0],
#         [ 90,  41,   1]],
#
#        [[227, 227, 239],
#         [219, 219, 231],
#         [215, 215, 225],
#         ...,
#         [ 94,  39,   0],
#         [ 91,  39,   0],
#         [ 88,  39,   0]],
#
#        [[227, 227, 239],
#         [220, 220, 232],
#         [216, 216, 226],
# ...
